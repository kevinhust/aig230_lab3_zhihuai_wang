# %% [markdown]
# # Lab 3 — Statistical Language Models (Practical Dev Pipeline)
#
# This notebook teaches **how a developer would actually train, evaluate,
# and use a Statistical Language Model (SLM)** using a real dataset.
#
# The goal is not just theory, but a **repeatable NLP pipeline**.
#
# ---
#
# ## What you will learn
#
# - Loading and preparing a real corpus
# - Train / validation / test splitting
# - Vocabulary construction and OOV handling
# - Training unigram, bigram, and trigram models
# - Smoothing and why it is required
# - Evaluating with perplexity
# - Using an SLM for next-word prediction

# %% [markdown]
# ## 1. Setup

# %%
# %pip install nltk numpy pandas
# Out:
# Requirement already satisfied: nltk in /opt/anaconda3/envs/ocv/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/ocv/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/ocv/lib/python3.12/site-packages (3.0.0)
# Requirement already satisfied: click in /opt/anaconda3/envs/ocv/lib/python3.12/site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/ocv/lib/python3.12/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/ocv/lib/python3.12/site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/ocv/lib/python3.12/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/ocv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ocv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
import re
import math
import random
from collections import Counter
from typing import List

nltk.download("reuters")
# Out:
# [nltk_data] Downloading package reuters to
# [nltk_data]     /Users/kevinwang/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# True

# %% [markdown]
# https://trec.nist.gov/data/reuters/reuters.html

# %% [markdown]
# ## 2. Load a real dataset (Reuters)

# %%
from nltk.corpus import reuters

# reuters.fileids() returns IDs for all documents.
# reuters.raw(fid) returns raw text for each document.
# We collect all documents into a Python list.

docs = [reuters.raw(fid) for fid in reuters.fileids()]
len(docs)
# Out:
# 10788

# %% [markdown]
# ## 3. Train / validation / test split

# %%
# Shuffle and split
random.seed(42)
random.shuffle(docs)

train_size = 6000
val_size = 1000
test_size = 1000

# Ensure consistent sizing if dataset changes, but respect the requested output structure
train_docs = docs[:train_size]
val_docs = docs[train_size : train_size+val_size]
test_docs = docs[train_size+val_size : train_size+val_size+test_size]

len(train_docs), len(val_docs), len(test_docs)
# Out:
# (6000, 1000, 1000)

# %% [markdown]
# ## 4. Tokenization and normalization

# %%
print(train_docs [0])
# Out:
# LOWER U.S. SOYBEAN LOAN IDEA SHARPLY CRITICIZED
#   U.S. soybean lobbyists and
#   congressional aides criticized a proposal from a senior
#   Agriculture Department official that Congress allow the U.S.
#   soybean loan level to be officially lowered to 4.56 dlrs per
#   bushel next year.
#       "I don't know who in Congress would propose that happening.
#   Politically it would be totally unacceptable," an aide to a
#   senior farm-state senator said.
#       USDA undersecretary Daniel Amstutz said this week that
#   Congress should give USDA authority to keep the soybean loan
#   at its current effective rate of 4.56 dlrs per bushel rather
#   than increasing it to its minimum allowed level of 4.77 dlrs.
#       "I'm convinced that Congress will not go along with this,"
#   American Soybean Association President Dave Haggard said.
#       Amstutz told reporters following a senate hearing that if
#   the soybean loan rate were 4.56 dlrs, USDA could then consider
#   ways to make U.S. soybeans more competitive.
#       His comments were seen as possibly indicating what the  the
#   administration's position is in the debate over what should be
#   done to make soybeans competitive and at the same time protect
#   soybean farmers' income.
#       Using soybean specific certificates to further buydown the
#   loan rate or implementation of a marketing loan have been
#   pointed to as the most effective ways to get soybean prices
#   competitive. USDA secretary Richard Lyng, however, continues to
#   maintain his opposition to a marketing loan, saying such a move
#   would be too costly.
#       "There will be alot of other options that will be
#   considered before Congress looks at that one (the Amstutz
#   proposal," said Bill O'Conner, aide to Rep. Edward Madigan
#   (R-Ill), ranking minority leader of the Agriculture Committee.
#       "Anybody representing large groups of soybean producers
#   would not be very excited about supporting a lower soybean
#   loan," O'Conner said.
#       Congress may very likely look at the soybean loan and
#   decide that they cannot increase it from its current 5.02 dlr
#   basic rate, but that there has to be something mandated to
#   increase soybean's competitiveness, David Graves, aide to Sen.
#   Thad Cochran (R-Miss) said. Cochran, a staunch supporter of a
#   soybean marketing loan, would support a soybean loan of 5.02 or
#   4.77 dlrs with a certificate buydown, Graves said.

# %%
# Defines a reusable tokenization function.
# Explicit, deterministic preprocessing is critical in NLP pipelines.

def tokenize(text: str) -> List[str]:
    text = text.lower()  # Lowercases text to reduce vocabulary size.
    text = re.sub(r"[^a-z0-9\s]+", " ", text)  # Removes punctuation. Keeps letters and numbers. Numbers matter in Reuters (prices, years, quantities).
    text = re.sub(r"\s+", " ", text).strip()  # Collapses multiple spaces. Removes leading and trailing whitespace.
    return text.split()  # Converts string into a list of tokens. Splits on spaces.

tokenize(train_docs[0])[:20]
# Out:
# ['lower',
#  'u',
#  's',
#  'soybean',
#  'loan',
#  'idea',
#  'sharply',
#  'criticized',
#  'u',
#  's',
#  'soybean',
#  'lobbyists',
#  'and',
#  'congressional',
#  'aides',
#  'criticized',
#  'a',
#  'proposal',
#  'from',
#  'a']

# %% [markdown]
# ## 5. Vocabulary and OOV handling

# %%
train_tokens = []
for d in train_docs:
    train_tokens.extend(tokenize(d))  # Tokenizes every training document. Flattens them into a single list.

freq = Counter(train_tokens)  # Counts word frequencies in the training set. This frequency distribution defines the vocabulary.
print(freq.most_common(10))  # Displays the 10 most common words and their counts

MIN_COUNT = 5  # Threshold for keeping words. Rare words cause unreliable probability estimates.
vocab = {w for w, c in freq.items() if c >= MIN_COUNT}  # Keeps only words that occur at least MIN_COUNT times. Keeps only sufficiently frequent tokens. Reduces noise and model size.
""" Why these tokens are mandatory
<UNK>: unknown words at inference time
<s>: sentence start
</s>: sentence end 
Without them:
SLMs break on unseen text
Sentence modeling becomes impossible"""
vocab |= {"<UNK>", "<s>", "</s>"}

len(vocab)
# Out:
# [('the', 38163), ('of', 20464), ('to', 19921), ('in', 16238), ('and', 14100), ('said', 14089), ('a', 13811), ('mln', 10604), ('s', 8564), ('vs', 8149)]
# 8773

# %%
def replace_oov(tokens, vocab=vocab):
    return [t if t in vocab else "<UNK>" for t in tokens]

def add_boundaries(tokens, n):
    return ["<s>"] * (n-1) + tokens + ["</s>"]

def get_ngrams(tokens: List[str], n: int):
    """Generates n-grams from a list of tokens."""
    return [tuple(tokens[i:i+n]) for i in range(len(tokens)-n+1)]

def train_ngram(docs, n):
    """Trains an n-gram language model by counting n-grams and their contexts."""
    ngram_counts = Counter()
    context_counts = Counter()
    
    for d in docs:
        tokens = replace_oov(tokenize(d), vocab)
        tokens = add_boundaries(tokens, n)
        for ng in get_ngrams(tokens, n):
            ngram_counts[ng] += 1
            context_counts[ng[:-1]] += 1
            
    return ngram_counts, context_counts

print("Training N-gram models...")
uni_counts, uni_ctx = train_ngram(train_docs, 1)
bi_counts, bi_ctx   = train_ngram(train_docs, 2)
tri_counts, tri_ctx = train_ngram(train_docs, 3)
print("Done.")
# Out:
# Training N-gram models...
# Done.

# %%
# Print vocabulary size and a few examples
print(f"Vocabulary Size: {len(vocab)}")
print(f"First 10 items: {sorted(list(vocab))[:10]}")
# Out:
# Vocabulary Size: 8773
# First 10 items: ['0', '00', '000', '0000', '001', '002', '003', '004', '005', '006']

# %%
# Count occurrences of the word "gain"
word = "gain"
print(f"Count of '{word}': {freq[word]}")
print(f"Is '{word}' in vocab? {word in vocab}")
# Out:
# Count of 'gain': 442
# Is 'gain' in vocab? True

# %%
# Count total words in train tokens
print(f"Total training tokens: {len(train_tokens)}")
# Out:
# Total training tokens: 818928

# %% [markdown]
# ## 6. Sentence boundaries

# %%
def add_boundaries(tokens: List[str], n: int):
    return ["<s>"]*(n-1) + tokens + ["</s>"]

# %% [markdown]
# ## 7. Replace OOV tokens

# %%
def replace_oov(tokens: List[str], vocab=vocab):

    """Centralizes unknown-word handling. Ensures consistency across train/val/test.
    Any unseen word becomes <UNK>. Prevents KeyErrors and zero-probability issues."""
    return [t if t in vocab else "<UNK>" for t in tokens]

# %% [markdown]
# ## 8. Train n-gram models

# %%
def replace_oov(tokens: List[str], vocab=vocab):
    """Centralizes unknown-word handling. Ensures consistency across train/val/test.
    Any unseen word becomes <UNK>. Prevents KeyErrors and zero-probability issues."""
    return [t if t in vocab else "<UNK>" for t in tokens]

uni_counts, uni_ctx = train_ngram(train_docs, 1)  # Trains unigram model.
bi_counts, bi_ctx   = train_ngram(train_docs, 2)  # Trains bigram model.
tri_counts, tri_ctx = train_ngram(train_docs, 3)  # Trains trigram model.

# %%
# Print bigram counts
bi_counts
# Out:
# Counter({('in', 'the'): 3712,
#          ('of', 'the'): 3711,
#          ('lt', '<UNK>'): 3205,
#          ('u', 's'): 3056,
#          ('said', 'the'): 2979,
#          ('mln', 'dlrs'): 2533,
#          ('said', 'it'): 2457,
#          ('mln', 'vs'): 2246,
#          ('<UNK>', '<UNK>'): 1919,
#          ('cts', 'vs'): 1839,
#          ('the', 'company'): 1788,
#          ('for', 'the'): 1551,
#          ('000', 'vs'): 1413,
#          ('he', 'said'): 1384,
#          ('to', 'the'): 1344,
#          ('the', '<UNK>'): 1275,
#          ('cts', 'net'): 1228,
#          ('the', 'u'): 1190,
#          ('on', 'the'): 1084,
#          ('<s>', '<UNK>'): 1005,
#          ('vs', 'loss'): 1003,
#          ('<UNK>', 'and'): 993,
#          ('dlrs', 'in'): 951,
#          ('pct', 'of'): 942,
#          ('billion', 'dlrs'): 913,
#          ('to', 'be'): 911,
#          ('<UNK>', 'said'): 897,
#          ('it', 'said'): 882,
#          ('and', 'the'): 878,
#          ('<UNK>', 'the'): 872,
#          ('and', '<UNK>'): 872,
#          ('000', 'dlrs'): 869,
#          ('will', 'be'): 855,
#          ('of', '<UNK>'): 852,
#          ('<UNK>', 'of'): 842,
#          ('by', 'the'): 839,
#          ('in', 'a'): 819,
#          ('5', 'mln'): 789,
#          ('with', 'the'): 779,
#          ('that', 'the'): 774,
#          ('pct', 'in'): 766,
#          ('last', 'year'): 760,
#          ('<UNK>', 'to'): 748,
#          ('to', '<UNK>'): 740,
#          ('inc', 'lt'): 738,
#          ('at', 'the'): 719,
#          ('from', 'the'): 719,
#          ('company', 'said'): 708,
#          ('dlrs', 'vs'): 707,
#          ('a', 'share'): 702,
#          ('vs', '1'): 673,
#          ('000', 'revs'): 664,
#          ('<UNK>', 'in'): 661,
#          ('6', 'mln'): 643,
#          ('2', 'mln'): 638,
#          ('3', 'mln'): 636,
#          ('1', 'mln'): 632,
#          ('in', '1986'): 630,
#          ('of', 'a'): 626,
#          ('8', 'mln'): 624,
#          ('of', 'its'): 622,
#          ('net', 'shr'): 621,
#          ('corp', 'lt'): 619,
#          ('avg', 'shrs'): 615,
#          ('4', 'mln'): 611,
#          ('000', 'tonnes'): 609,
#          ('7', 'mln'): 595,
#          ('would', 'be'): 592,
#          ('this', 'year'): 590,
#          ('per', 'share'): 589,
#          ('the', 'dollar'): 584,
#          ('vs', 'profit'): 580,
#          ('a', '<UNK>'): 575,
#          ('9', 'mln'): 574,
#          ('said', '</s>'): 562,
#          ('0', 'mln'): 561,
#          ('mln', 'stg'): 560,
#          ('dlrs', 'a'): 556,
#          ('to', 'a'): 544,
#          ('net', 'loss'): 538,
#          ('said', 'he'): 535,
#          ('in', 'january'): 534,
#          ('said', 'in'): 530,
#          ('in', 'february'): 526,
#          ('the', 'bank'): 522,
#          ('dlrs', 'or'): 512,
#          ('it', 'has'): 502,
#          ('inc', 'said'): 494,
#          ('bank', 'of'): 493,
#          ('shr', 'loss'): 489,
#          ('4th', 'qtr'): 487,
#          ('said', 'that'): 484,
#          ('expected', 'to'): 481,
#          ('in', '<UNK>'): 465,
#          ('qtr', 'net'): 461,
#          ('mln', 'tonnes'): 460,
#          ('the', 'first'): 455,
#          ('it', 'is'): 454,
#          ('said', 'its'): 448,
#          ('the', 'government'): 442,
#          ('a', 'year'): 439,
#          ('mln', 'note'): 430,
#          ('net', 'profit'): 419,
#          ('in', '1985'): 413,
#          ('compared', 'with'): 409,
#          ('has', 'been'): 401,
#          ('for', 'a'): 400,
#          ('the', 'year'): 399,
#          ('5', 'pct'): 399,
#          ('tonnes', 'of'): 396,
#          ('as', 'a'): 395,
#          ('corp', 'said'): 394,
#          ('to', 'buy'): 387,
#          ('the', 'united'): 386,
#          ('mln', 'avg'): 381,
#          ('due', 'to'): 377,
#          ('<UNK>', 'inc'): 374,
#          ('it', 'will'): 367,
#          ('<UNK>', 'a'): 366,
#          ('cts', 'a'): 364,
#          ('united', 'states'): 359,
#          ('the', 'new'): 356,
#          ('said', '<UNK>'): 353,
#          ('company', 's'): 351,
#          ('vs', '2'): 351,
#          ('dlrs', 'net'): 350,
#          ('the', 'market'): 350,
#          ('u', 'k'): 350,
#          ('pct', 'from'): 349,
#          ('billion', 'vs'): 349,
#          ('sale', 'of'): 347,
#          ('dlrs', 'per'): 342,
#          ('did', 'not'): 339,
#          ('oper', 'net'): 339,
#          ('<UNK>', 'corp'): 337,
#          ('more', 'than'): 337,
#          ('nine', 'mths'): 337,
#          ('sources', 'said'): 332,
#          ('at', 'a'): 330,
#          ('mths', 'shr'): 327,
#          ('s', '<UNK>'): 327,
#          ('<s>', 'u'): 322,
#          ('it', 'was'): 320,
#          ('end', 'of'): 320,
#          ('also', 'said'): 319,
#          ('said', 'they'): 318,
#          ('central', 'bank'): 318,
#          ('they', 'said'): 317,
#          ('3rd', 'qtr'): 317,
#          ('first', 'quarter'): 315,
#          ('mln', '</s>'): 314,
#          ('to', 'sell'): 312,
#          ('4', 'pct'): 308,
#          ('and', 'a'): 306,
#          ('of', '1'): 304,
#          ('with', 'a'): 303,
#          ('1986', '87'): 303,
#          ('<UNK>', '4th'): 301,
#          ('2', 'pct'): 300,
#          ('oper', 'shr'): 299,
#          ('the', 'sale'): 299,
#          ('the', 'end'): 297,
#          ('agreed', 'to'): 296,
#          ('on', 'a'): 295,
#          ('is', 'expected'): 295,
#          ('1', '2'): 294,
#          ('dlrs', 'from'): 294,
#          ('1st', 'qtr'): 293,
#          ('in', 'its'): 292,
#          ('<UNK>', 'for'): 288,
#          ('shr', 'profit'): 287,
#          ('vs', '3'): 287,
#          ('stake', 'in'): 287,
#          ('the', 'same'): 286,
#          ('up', 'to'): 286,
#          ('to', 'acquire'): 286,
#          ('new', 'york'): 285,
#          ('000', 'sales'): 283,
#          ('in', '1987'): 283,
#          ('over', 'the'): 282,
#          ('year', 'shr'): 282,
#          ('had', 'been'): 279,
#          ('it', 'would'): 278,
#          ('spokesman', 'said'): 278,
#          ('under', 'the'): 278,
#          ('common', 'stock'): 278,
#          ('because', 'of'): 277,
#          ('<UNK>', 'lt'): 276,
#          ('<UNK>', 'o'): 273,
#          ('that', 'it'): 272,
#          ('mln', 'revs'): 268,
#          ('rise', 'in'): 266,
#          ('the', 'current'): 263,
#          ('have', 'been'): 262,
#          ('<UNK>', 'by'): 260,
#          ('dlrs', 'and'): 259,
#          ('last', 'month'): 258,
#          ('cts', 'per'): 256,
#          ('loss', '1'): 253,
#          ('<UNK>', 's'): 251,
#          ('from', 'a'): 247,
#          ('year', 'ago'): 247,
#          ('pct', 'to'): 247,
#          ('qtly', 'div'): 245,
#          ('be', '<UNK>'): 242,
#          ('8', 'pct'): 241,
#          ('the', 'group'): 240,
#          ('last', 'week'): 240,
#          ('department', 'said'): 240,
#          ('mln', 'dlr'): 239,
#          ('cts', 'prior'): 239,
#          ('he', 'added'): 238,
#          ('analysts', 'said'): 237,
#          ('money', 'market'): 236,
#          ('a', 'new'): 235,
#          ('loss', 'of'): 234,
#          ('shares', 'of'): 233,
#          ('told', 'reuters'): 233,
#          ('its', '<UNK>'): 228,
#          ('is', 'a'): 228,
#          ('part', 'of'): 228,
#          ('interest', 'rates'): 228,
#          ('billion', 'in'): 227,
#          ('said', 'a'): 227,
#          ('sales', 'of'): 226,
#          ('1', 'pct'): 225,
#          ('if', 'the'): 224,
#          ('march', '31'): 222,
#          ('dlrs', 'for'): 222,
#          ('of', 'about'): 221,
#          ('mln', 'in'): 221,
#          ('foreign', 'exchange'): 220,
#          ('oil', 'and'): 220,
#          ('and', 'other'): 218,
#          ('crude', 'oil'): 218,
#          ('during', 'the'): 217,
#          ('cts', 'oper'): 215,
#          ('against', 'the'): 214,
#          ('dlrs', '</s>'): 213,
#          ('9', 'pct'): 212,
#          ('rose', 'to'): 212,
#          ('would', 'not'): 210,
#          ('09', '87'): 210,
#          ('the', 'world'): 209,
#          ('but', 'the'): 209,
#          ('increase', 'in'): 209,
#          ('likely', 'to'): 208,
#          ('after', 'a'): 208,
#          ('to', 'take'): 208,
#          ('according', 'to'): 207,
#          ('<UNK>', 'on'): 205,
#          ('the', 'two'): 205,
#          ('the', 'federal'): 205,
#          ('the', 'previous'): 205,
#          ('west', 'germany'): 204,
#          ('common', 'shares'): 203,
#          ('plans', 'to'): 202,
#          ('the', 'central'): 202,
#          ('officials', 'said'): 201,
#          ('shr', '1'): 201,
#          ('1986', 'the'): 200,
#          ('7', 'pct'): 199,
#          ('it', 'had'): 198,
#          ('dealers', 'said'): 198,
#          ('3', 'pct'): 198,
#          ('net', 'includes'): 197,
#          ('as', 'the'): 196,
#          ('to', '1'): 196,
#          ('for', '<UNK>'): 196,
#          ('year', 'net'): 195,
#          ('dlrs', 'to'): 195,
#          ('a', 'statement'): 195,
#          ('the', 'department'): 195,
#          ('vs', '4'): 193,
#          ('co', 'lt'): 192,
#          ('it', 'expects'): 191,
#          ('the', 'fed'): 190,
#          ('after', 'the'): 190,
#          ('and', 'co'): 189,
#          ('year', 'the'): 189,
#          ('dlrs', 'of'): 189,
#          ('dlrs', 'the'): 189,
#          ('year', 'earlier'): 189,
#          ('nil', 'nil'): 189,
#          ('6', 'pct'): 188,
#          ('by', 'a'): 188,
#          ('prior', 'pay'): 186,
#          ('stock', 'split'): 185,
#          ('the', 'next'): 184,
#          ('1', '5'): 184,
#          ('does', 'not'): 183,
#          ('mln', 'year'): 182,
#          ('which', 'is'): 182,
#          ('the', 'ec'): 182,
#          ('ltd', 'lt'): 180,
#          ('loss', 'shr'): 179,
#          ('of', 'u'): 178,
#          ('s', 'trade'): 178,
#          ('oil', 'prices'): 178,
#          ('vs', '5'): 177,
#          ('in', 'december'): 177,
#          ('<UNK>', 'that'): 177,
#          ('at', '<UNK>'): 176,
#          ('securities', 'and'): 176,
#          ('is', 'not'): 176,
#          ('record', 'april'): 176,
#          ('is', '<UNK>'): 175,
#          ('buffer', 'stock'): 175,
#          ('rate', 'of'): 174,
#          ('fourth', 'quarter'): 174,
#          ('5', 'billion'): 174,
#          ('share', 'in'): 174,
#          ('<UNK>', '</s>'): 174,
#          ('year', 's'): 174,
#          ('net', '1'): 173,
#          ('at', 'least'): 173,
#          ('tender', 'offer'): 173,
#          ('the', 'agreement'): 173,
#          ('gain', 'of'): 172,
#          ('interest', 'in'): 172,
#          ('to', 'make'): 171,
#          ('acquisition', 'of'): 171,
#          ('its', 'board'): 171,
#          ('jan', '31'): 170,
#          ('the', 'offer'): 170,
#          ('mln', 'shares'): 169,
#          ('the', 'merger'): 169,
#          ('subject', 'to'): 168,
#          ('3', '4'): 168,
#          ('quarter', 'and'): 168,
#          ('by', '<UNK>'): 167,
#          ('10', 'pct'): 167,
#          ('official', 'said'): 167,
#          ('the', 'country'): 167,
#          ('one', 'of'): 166,
#          ('japan', 's'): 165,
#          ('the', 'total'): 165,
#          ('industries', 'inc'): 165,
#          ('there', 'is'): 165,
#          ('in', 'march'): 165,
#          ('<UNK>', 'with'): 164,
#          ('the', 'acquisition'): 164,
#          ('the', 'second'): 164,
#          ('such', 'as'): 164,
#          ('bank', 'said'): 163,
#          ('<s>', 'lt'): 163,
#          ('were', 'not'): 162,
#          ('and', 'exchange'): 162,
#          ('have', 'to'): 162,
#          ('1985', '86'): 162,
#          ('on', 'its'): 162,
#          ('record', 'march'): 161,
#          ('50', 'pct'): 161,
#          ('<UNK>', 'from'): 161,
#          ('based', 'on'): 161,
#          ('1', '4'): 161,
#          ('could', 'be'): 160,
#          ('<UNK>', 'at'): 160,
#          ('in', 'an'): 160,
#          ('is', 'the'): 158,
#          ('number', 'of'): 158,
#          ('will', 'not'): 157,
#          ('of', '1986'): 157,
#          ('to', 'have'): 157,
#          ('s', 'agriculture'): 157,
#          ('the', 'price'): 157,
#          ('was', 'not'): 157,
#          ('tonnes', 'in'): 157,
#          ('the', 'securities'): 156,
#          ('exchange', 'commission'): 156,
#          ('50', 'dlrs'): 156,
#          ('an', '<UNK>'): 156,
#          ('on', 'march'): 155,
#          ('two', 'cts'): 155,
#          ('of', 'japan'): 155,
#          ('should', 'be'): 154,
#          ('loss', '2'): 154,
#          ('about', 'the'): 154,
#          ('value', 'of'): 154,
#          ('would', 'have'): 154,
#          ('1987', '88'): 153,
#          ('and', 'that'): 153,
#          ('<UNK>', 'sets'): 152,
#          ('qtr', 'loss'): 151,
#          ('agriculture', 'department'): 150,
#          ('the', 'past'): 150,
#          ('the', 'yen'): 150,
#          ('up', 'from'): 149,
#          ('west', 'german'): 149,
#          ('not', 'be'): 148,
#          ('year', 'and'): 148,
#          ('plc', 'lt'): 148,
#          ('1986', '</s>'): 148,
#          ('this', 'week'): 147,
#          ('co', 'said'): 147,
#          ('mln', 'nine'): 147,
#          ('shares', 'or'): 147,
#          ('mln', 'barrels'): 147,
#          ('told', 'the'): 147,
#          ('a', 'barrel'): 147,
#          ('the', 'international'): 147,
#          ('10', 'cts'): 146,
#          ('five', 'pct'): 146,
#          ('billion', 'stg'): 146,
#          ('20', 'pct'): 145,
#          ('price', 'of'): 145,
#          ('<UNK>', '3rd'): 144,
#          ('trade', 'deficit'): 144,
#          ('a', 'major'): 144,
#          ('declined', 'to'): 144,
#          ('share', 'for'): 142,
#          ('expects', 'to'): 141,
#          ('the', 'european'): 141,
#          ('pay', 'april'): 140,
#          ('said', 'there'): 140,
#          ('the', 'week'): 139,
#          ('s', 'and'): 139,
#          ('european', 'community'): 139,
#          ('offer', 'for'): 139,
#          ('and', 'gas'): 139,
#          ('note', '1986'): 138,
#          ('pct', 'the'): 138,
#          ('the', 'soviet'): 138,
#          ('of', 'england'): 138,
#          ('was', '<UNK>'): 138,
#          ('dlrs', 'on'): 137,
#          ('fell', 'to'): 137,
#          ('pct', 'stake'): 137,
#          ('when', 'the'): 137,
#          ('year', 'to'): 137,
#          ('long', 'term'): 137,
#          ('the', 'last'): 137,
#          ('billion', 'dlr'): 137,
#          ('growth', 'in'): 137,
#          ('for', 'an'): 136,
#          ('0', 'pct'): 136,
#          ('2nd', 'qtr'): 135,
#          ('vs', '6'): 135,
#          ('exchange', 'rate'): 135,
#          ('year', '</s>'): 135,
#          ('continue', 'to'): 135,
#          ('qtr', 'and'): 135,
#          ('discontinued', 'operations'): 135,
#          ('of', '3'): 134,
#          ('to', 'cut'): 134,
#          ('five', 'cts'): 134,
#          ('group', 'of'): 133,
#          ('of', '2'): 133,
#          ('for', 'one'): 133,
#          ('the', 'gulf'): 133,
#          ('natural', 'gas'): 133,
#          ('<UNK>', 'is'): 132,
#          ('and', 'will'): 132,
#          ('<UNK>', '1st'): 132,
#          ('qtr', 'jan'): 132,
#          ('the', 'official'): 132,
#          ('into', 'the'): 132,
#          ('out', 'of'): 131,
#          ('federal', 'reserve'): 131,
#          ('trade', 'surplus'): 131,
#          ('soviet', 'union'): 130,
#          ('terms', 'of'): 129,
#          ('short', 'term'): 128,
#          ('the', 'trade'): 128,
#          ('<UNK>', 'l'): 128,
#          ('from', '<UNK>'): 128,
#          ('1986', 'net'): 128,
#          ('31', 'net'): 128,
#          ('1986', 'and'): 128,
#          ('said', 'this'): 127,
#          ('2', '5'): 127,
#          ('amount', 'of'): 126,
#          ('told', 'a'): 126,
#          ('to', '2'): 126,
#          ('25', 'pct'): 126,
#          ('a', 'total'): 126,
#          ('we', 'are'): 125,
#          ('which', 'has'): 125,
#          ('six', 'cts'): 125,
#          ('to', 'its'): 124,
#          ('to', 'increase'): 124,
#          ('the', 'fourth'): 124,
#          ('and', 'to'): 124,
#          ('pct', 'and'): 124,
#          ('there', 'was'): 124,
#          ('traders', 'said'): 124,
#          ('it', 's'): 123,
#          ('of', 'this'): 123,
#          ('the', '1986'): 123,
#          ('money', 'supply'): 123,
#          ('owned', 'by'): 122,
#          ('less', 'than'): 122,
#          ('current', 'account'): 121,
#          ('ltd', 'said'): 121,
#          ('vs', '8'): 121,
#          ('from', '1'): 121,
#          ('before', 'the'): 121,
#          ('be', 'a'): 121,
#          ('qtr', 'shr'): 121,
#          ('<UNK>', 'has'): 120,
#          ('group', 'inc'): 120,
#          ('government', 's'): 120,
#          ('three', 'cts'): 120,
#          ('the', 'state'): 119,
#          ('exchange', 'rates'): 119,
#          ('billion', 'marks'): 119,
#          ('quarter', 'of'): 119,
#          ('of', '1987'): 119,
#          ('stg', 'vs'): 119,
#          ('it', 'also'): 118,
#          ('since', 'the'): 118,
#          ('on', 'april'): 118,
#          ('the', 'national'): 118,
#          ('between', 'the'): 118,
#          ('the', 'report'): 118,
#          ('was', 'a'): 118,
#          ('an', 'agreement'): 118,
#          ('000', 'note'): 118,
#          ('of', 'record'): 118,
#          ('2', 'billion'): 118,
#          ('net', 'income'): 118,
#          ('the', 'transaction'): 117,
#          ('and', 'its'): 117,
#          ('the', 'bundesbank'): 117,
#          ('of', 'an'): 117,
#          ('may', 'be'): 116,
#          ('fall', 'in'): 116,
#          ('and', '1'): 116,
#          ('a', 'result'): 116,
#          ('told', 'reporters'): 115,
#          ('profit', '1'): 115,
#          ('but', 'he'): 115,
#          ('in', 'cash'): 115,
#          ('vs', '10'): 115,
#          ('seasonally', 'adjusted'): 115,
#          ('down', 'from'): 115,
#          ('<UNK>', 'its'): 115,
#          ('the', 'economy'): 115,
#          ('the', 'stock'): 114,
#          ('vs', '11'): 113,
#          ('to', 'help'): 113,
#          ('the', 'third'): 112,
#          ('of', 'new'): 112,
#          ('added', 'that'): 112,
#          ('net', 'excludes'): 112,
#          ('vs', '9'): 111,
#          ('s', 'lt'): 111,
#          ('share', 'of'): 111,
#          ('control', 'of'): 111,
#          ('a', 'further'): 111,
#          ('said', 'but'): 111,
#          ('half', 'of'): 111,
#          ('the', 'board'): 111,
#          ('result', 'of'): 111,
#          ('<UNK>', 'it'): 110,
#          ('<UNK>', 'as'): 110,
#          ('year', 'on'): 110,
#          ('a', 'record'): 110,
#          ('1', '1'): 110,
#          ('stg', 'in'): 110,
#          ('vs', '7'): 110,
#          ('four', 'cts'): 110,
#          ('president', 'of'): 109,
#          ('net', '2'): 109,
#          ('not', '<UNK>'): 109,
#          ('level', 'of'): 108,
#          ('he', 'told'): 108,
#          ('the', 'proposed'): 108,
#          ('as', 'well'): 108,
#          ('january', 'and'): 108,
#          ('february', '1986'): 108,
#          ('have', 'a'): 108,
#          ('bid', 'for'): 108,
#          ('but', 'it'): 107,
#          ('feb', '28'): 107,
#          ('in', 'addition'): 107,
#          ('is', 'to'): 107,
#          ('than', 'the'): 107,
#          ('assets', 'of'): 107,
#          ('<UNK>', 'year'): 107,
#          ('a', 'spokesman'): 107,
#          ('<UNK>', 'told'): 107,
#          ('to', 'an'): 107,
#          ('we', 'have'): 106,
#          ('will', 'have'): 106,
#          ('in', 'april'): 106,
#          ('country', 's'): 106,
#          ('04', '09'): 106,
#          ('87', '03'): 106,
#          ('1', '<UNK>'): 106,
#          ('exports', 'to'): 105,
#          ('hong', 'kong'): 105,
#          ('eight', 'cts'): 105,
#          ('the', 'japanese'): 105,
#          ('mln', 'bpd'): 105,
#          ('the', 'paris'): 104,
#          ('compared', 'to'): 104,
#          ('cost', 'of'): 104,
#          ('with', '<UNK>'): 104,
#          ('6', 'billion'): 104,
#          ('1', 'billion'): 104,
#          ('03', '09'): 104,
#          ('at', '1'): 104,
#          ('the', 'sources'): 103,
#          ('subsidiary', 'of'): 103,
#          ('fiscal', 'year'): 103,
#          ('south', 'korea'): 103,
#          ('he', 'was'): 103,
#          ('april', '30'): 103,
#          ('been', '<UNK>'): 102,
#          ('for', '1986'): 102,
#          ('to', 'pay'): 102,
#          ('<UNK>', 'but'): 102,
#          ('previously', 'announced'): 102,
#          ('this', 'month'): 101,
#          ('16', 'pct'): 101,
#          ('nine', 'cts'): 101,
#          ('3', 'billion'): 101,
#          ('to', 'reduce'): 101,
#          ('was', 'the'): 101,
#          ('of', 'oil'): 101,
#          ('comment', 'on'): 100,
#          ('<UNK>', 'he'): 100,
#          ('are', 'not'): 100,
#          ('talks', 'with'): 100,
#          ('<UNK>', 'will'): 100,
#          ('not', 'to'): 100,
#          ('the', 'money'): 100,
#          ('shares', 'in'): 100,
#          ('a', 'loss'): 100,
#          ('full', 'name'): 99,
#          ('in', 'new'): 99,
#          ('chief', 'executive'): 99,
#          ('third', 'quarter'): 99,
#          ('<UNK>', 'was'): 99,
#          ('s', 'a'): 99,
#          ('co', 'inc'): 99,
#          ('april', '15'): 99,
#          ('has', 'not'): 99,
#          ('to', 'meet'): 99,
#          ('drop', 'in'): 99,
#          ('change', 'in'): 98,
#          ('000', 'shares'): 98,
#          ('1', '8'): 98,
#          ('well', 'as'): 98,
#          ('50', 'cts'): 98,
#          ('000', '</s>'): 98,
#          ('to', 'rise'): 98,
#          ('12', 'cts'): 98,
#          ('pct', 'rise'): 98,
#          ('pct', '</s>'): 98,
#          ('for', 'all'): 98,
#          ('total', 'of'): 98,
#          ('response', 'to'): 97,
#          ('today', 's'): 97,
#          ('to', '10'): 97,
#          ('bank', 's'): 97,
#          ('8', 'billion'): 97,
#          ('<UNK>', 'which'): 96,
#          ('plan', 'to'): 96,
#          ('<UNK>', 'group'): 96,
#          ('nine', 'months'): 96,
#          ('1', '3'): 96,
#          ('saudi', 'arabia'): 96,
#          ('31', 'shr'): 96,
#          ('six', 'mths'): 95,
#          ('to', '7'): 95,
#          ('<UNK>', 'co'): 95,
#          ('500', '000'): 95,
#          ('one', 'mln'): 95,
#          ('vs', '12'): 95,
#          ('months', 'of'): 95,
#          ('a', 'u'): 95,
#          ('minister', '<UNK>'): 95,
#          ('4', '2'): 95,
#          ('international', 'inc'): 94,
#          ('for', 'its'): 94,
#          ('the', 'spokesman'): 94,
#          ('<UNK>', 'sees'): 94,
#          ('meeting', 'of'): 94,
#          ('operations', 'of'): 94,
#          ('six', 'months'): 94,
#          ('100', '000'): 94,
#          ('that', 'a'): 94,
#          ('group', 'said'): 94,
#          ('17', 'cts'): 93,
#          ('net', 'oper'): 93,
#          ('qtr', 'feb'): 93,
#          ('economists', 'said'): 93,
#          ('seven', 'cts'): 93,
#          ('chairman', 'of'): 93,
#          ('decline', 'in'): 93,
#          ('one', 'ct'): 93,
#          ('15', 'pct'): 93,
#          ('offer', 'to'): 93,
#          ('don', 't'): 92,
#          ('sell', 'its'): 92,
#          ('all', 'of'): 92,
#          ('on', 'year'): 92,
#          ('year', 'oper'): 92,
#          ('earlier', 'this'): 92,
#          ('has', 'a'): 92,
#          ('20', 'cts'): 92,
#          ('15', 'cts'): 92,
#          ('to', 'keep'): 91,
#          ('co', 'ltd'): 91,
#          ('are', 'expected'): 91,
#          ('pct', 'interest'): 91,
#          ('000', 'year'): 91,
#          ('to', '3'): 91,
#          ('that', 'would'): 91,
#          ('for', '1987'): 91,
#          ('do', 'not'): 91,
#          ('interest', 'rate'): 91,
#          ('pre', 'tax'): 91,
#          ('says', 'it'): 91,
#          ('share', 'from'): 91,
#          ('were', '<UNK>'): 90,
#          ('<s>', 'japan'): 90,
#          ('from', 'discontinued'): 90,
#          ('for', 'about'): 90,
#          ('per', 'tonne'): 90,
#          ('at', 'its'): 89,
#          ('not', 'disclosed'): 89,
#          ('the', 'other'): 89,
#          ('9', 'billion'): 89,
#          ('holders', 'of'): 89,
#          ('the', 'purchase'): 89,
#          ('noted', 'that'): 89,
#          ('they', 'are'): 89,
#          ('rate', 'to'): 88,
#          ('o', '3rd'): 88,
#          ('30', 'pct'): 88,
#          ('agreement', 'to'): 88,
#          ('in', 'quarter'): 88,
#          ('it', 'added'): 88,
#          ('if', 'it'): 88,
#          ('billion', 'francs'): 88,
#          ('to', 'continue'): 87,
#          ('a', 'letter'): 87,
#          ('and', 'is'): 87,
#          ('000', 'dlr'): 87,
#          ('revs', '1'): 87,
#          ('or', '1'): 87,
#          ('7', 'billion'): 87,
#          ('a', 'two'): 87,
#          ('in', 'u'): 87,
#          ('added', '</s>'): 87,
#          ('which', '<UNK>'): 87,
#          ('ended', 'march'): 86,
#          ('s', 'stock'): 86,
#          ('vs', '13'): 86,
#          ('<s>', 'fed'): 86,
#          ('while', 'the'): 86,
#          ('of', 'lt'): 86,
#          ('which', 'was'): 86,
#          ('so', 'far'): 86,
#          ('able', 'to'): 86,
#          ('year', 'from'): 86,
#          ('<UNK>', '2nd'): 86,
#          ('said', 'if'): 85,
#          ('the', 'latest'): 85,
#          ('s', 'dlrs'): 85,
#          ('filing', 'with'): 85,
#          ('<UNK>', 'ltd'): 85,
#          ('brazil', 's'): 85,
#          ('had', 'a'): 85,
#          ('finance', 'minister'): 85,
#          ('need', 'to'): 85,
#          ('going', 'to'): 84,
#          ('the', 'budget'): 84,
#          ('the', 'system'): 84,
#          ('said', 'we'): 84,
#          ('imports', 'of'): 84,
#          ('80', 'pct'): 84,
#          ('the', 'deal'): 84,
#          ('vice', 'president'): 83,
#          ('in', 'response'): 83,
#          ('inc', 'a'): 83,
#          ('20', 'mln'): 83,
#          ('in', 'may'): 83,
#          ('a', 'group'): 83,
#          ('that', '<UNK>'): 83,
#          ('2', 'cts'): 83,
#          ('1987', '</s>'): 83,
#          ('completed', 'the'): 83,
#          ('dec', '31'): 83,
#          ('the', 'main'): 83,
#          ('at', 'about'): 83,
#          ('25', 'dlrs'): 83,
#          ('an', 'increase'): 83,
#          ('and', 'said'): 83,
#          ('to', 'raise'): 83,
#          ('from', 'its'): 82,
#          ('an', 'average'): 82,
#          ('is', 'likely'): 82,
#          ('it', 'agreed'): 82,
#          ('on', '<UNK>'): 82,
#          ('its', 'stake'): 82,
#          ('some', 'of'): 82,
#          ('1985', 'the'): 82,
#          ('april', '1'): 82,
#          ('000', 'avg'): 82,
#          ('on', 'friday'): 82,
#          ('gave', 'no'): 82,
#          ('the', 'most'): 81,
#          ('there', 'are'): 81,
#          ('a', 'company'): 81,
#          ('a', 'filing'): 81,
#          ('the', 'shares'): 81,
#          ('in', 'paris'): 81,
#          ('in', 'which'): 81,
#          ('1987', 'and'): 81,
#          ('january', 'the'): 81,
#          ('prices', 'and'): 81,
#          ('10', 'mln'): 81,
#          ('revenues', 'of'): 81,
#          ('two', 'for'): 81,
#          ('the', '1987'): 81,
#          ('rose', '0'): 81,
#          ('preferred', 'stock'): 81,
#          ('week', 'ended'): 81,
#          ('for', 'two'): 80,
#          ('a', 'net'): 80,
#          ('net', '3'): 80,
#          ('has', '<UNK>'): 80,
#          ('pct', 'increase'): 80,
#          ('prices', 'for'): 80,
#          ('they', 'were'): 80,
#          ('will', 'continue'): 80,
#          ('it', 'to'): 79,
#          ('that', 'they'): 79,
#          ('signed', 'a'): 79,
#          ('because', 'the'): 79,
#          ('13', 'cts'): 79,
#          ('the', 'largest'): 79,
#          ('be', 'the'): 79,
#          ('the', 'meeting'): 79,
#          ('has', 'agreed'): 79,
#          ('cash', 'and'): 79,
#          ('are', '<UNK>'): 79,
#          ('a', 'meeting'): 79,
#          ('to', 'shareholders'): 79,
#          ('000', 'bpd'): 79,
#          ('2', '1'): 78,
#          ('is', 'also'): 78,
#          ('joint', 'venture'): 78,
#          ('the', 'value'): 78,
#          ('earnings', 'of'): 78,
#          ('i', 'think'): 78,
#          ('investment', 'in'): 78,
#          ('4', 'billion'): 78,
#          ('one', 'billion'): 78,
#          ('the', 'recent'): 78,
#          ('pay', 'may'): 78,
#          ('the', 'buffer'): 78,
#          ('of', '4'): 77,
#          ('when', 'it'): 77,
#          ('share', 'on'): 77,
#          ('mln', 'marks'): 77,
#          ('11', 'cts'): 77,
#          ('in', 'year'): 77,
#          ('the', 'industry'): 77,
#          ('year', 'in'): 77,
#          ('can', 'be'): 77,
#          ('to', 'do'): 77,
#          ('agreement', 'with'): 77,
#          ('with', 'its'): 77,
#          ('next', 'week'): 77,
#          ('m', '1'): 77,
#          ('of', 'one'): 77,
#          ('delegates', 'said'): 77,
#          ('rather', 'than'): 76,
#          ('such', 'a'): 76,
#          ('could', 'not'): 76,
#          ('2', '2'): 76,
#          ('and', 'trade'): 76,
#          ('to', 'fall'): 76,
#          ('<UNK>', 'an'): 76,
#          ('a', '1'): 76,
#          ('annual', 'meeting'): 76,
#          ('a', 'day'): 76,
#          ('the', 'administration'): 75,
#          ('is', 'in'): 75,
#          ('30', 'cts'): 75,
#          ('as', '<UNK>'): 75,
#          ('is', 'still'): 75,
#          ('and', 'chief'): 75,
#          ('to', 'purchase'): 75,
#          ('two', 'mln'): 75,
#          ('in', '1988'): 75,
#          ('after', 'tax'): 75,
#          ('profit', 'of'): 75,
#          ('higher', 'than'): 75,
#          ('to', 'give'): 75,
#          ('reagan', 'administration'): 75,
#          ('first', 'half'): 75,
#          ('following', 'the'): 75,
#          ('corp', 's'): 75,
#          ('<UNK>', 'industries'): 75,
#          ('to', 'see'): 75,
#          ('three', 'pct'): 75,
#          ('s', 'oil'): 75,
#          ('billion', 'yen'): 75,
#          ('in', 'london'): 75,
#          ('year', 'ended'): 74,
#          ('25', 'cts'): 74,
#          ('3', '8'): 74,
#          ('the', 'exchange'): 74,
#          ('28', 'net'): 74,
#          ('7', '1'): 74,
#          ('pct', 'on'): 74,
#          ('below', 'the'): 74,
#          ('the', 'proposal'): 74,
#          ('as', 'part'): 74,
#          ('above', 'the'): 74,
#          ('7', '8'): 74,
#          ('that', 'he'): 74,
#          ('to', 'end'): 74,
#          ('purchase', 'of'): 74,
#          ('he', 'did'): 74,
#          ('second', 'quarter'): 74,
#          ('it', '<UNK>'): 74,
#          ('the', 'full'): 74,
#          ('for', 'each'): 74,
#          ('december', '31'): 74,
#          ('led', 'by'): 74,
#          ('trade', 'sources'): 74,
#          ('this', 'morning'): 73,
#          ('500', 'mln'): 73,
#          ('<UNK>', 'up'): 73,
#          ('of', 'their'): 73,
#          ('dollar', 's'): 73,
#          ('the', 'annual'): 73,
#          ('the', 'time'): 73,
#          ('which', 'would'): 73,
#          ('14', 'cts'): 73,
#          ('two', 'pct'): 73,
#          ('profit', '2'): 73,
#          ('28', 'cts'): 72,
#          ('cts', 'shr'): 72,
#          ('which', 'will'): 72,
#          ('through', 'the'): 72,
#          ('of', 'around'): 72,
#          ('agreement', 'on'): 72,
#          ('300', '000'): 72,
#          ('news', 'conference'): 72,
#          ('england', 'said'): 72,
#          ('vs', '15'): 72,
#          ('spokesman', 'for'): 72,
#          ('there', 'were'): 72,
#          ('through', 'a'): 72,
#          ('the', 'amount'): 72,
#          ('monetary', 'policy'): 72,
#          ('billion', 'note'): 72,
#          ('at', 'an'): 72,
#          ('dlr', 'per'): 71,
#          ('the', 'export'): 71,
#          ('letter', 'of'): 71,
#          ('it', 'bought'): 71,
#          ('reported', 'a'): 71,
#          ('company', 'is'): 71,
#          ('prime', 'rate'): 71,
#          ('3', '5'): 71,
#          ('rise', 'to'): 71,
#          ('000', 'nine'): 71,
#          ('prior', 'year'): 71,
#          ('will', 'also'): 71,
#          ('be', 'made'): 71,
#          ('on', 'monday'): 71,
#          ('the', 'west'): 71,
#          ('week', 's'): 71,
#          ('the', 'plan'): 71,
#          ('stock', 'dividend'): 71,
#          ('has', 'said'): 71,
#          ('income', 'of'): 71,
#          ('decided', 'to'): 70,
#          ('company', 'to'): 70,
#          ('22', 'cts'): 70,
#          ('the', 'six'): 70,
#          ('dlrs', 'last'): 70,
#          ('the', 'issue'): 70,
#          ('the', 'increase'): 70,
#          ('to', 'support'): 70,
#          ('15', 'record'): 70,
#          ('full', 'year'): 70,
#          ('had', 'not'): 70,
#          ('report', 'said'): 70,
#          ('as', 'an'): 70,
#          ('and', '2'): 70,
#          ('tax', 'credits'): 70,
#          ('vs', '20'): 70,
#          ('in', 'recent'): 70,
#          ('per', 'day'): 70,
#          ('shareholders', 'of'): 70,
#          ('share', '</s>'): 70,
#          ('balance', 'of'): 70,
#          ('trade', 'and'): 69,
#          ('and', 'lt'): 69,
#          ('it', 'plans'): 69,
#          ...})

# %% [markdown]
# ## 9. Add-k smoothing

# %% [markdown]
# Add-k smoothing is a simple technique used in statistical language models to avoid zero probabilities for unseen events.
# In an n-gram language model, probabilities are estimated from counts.
#
# For a bigram model:
#
# P(w∣h)= count(h, w) / count(h)
# 	​
#
#
# If a word sequence never appeared in the training data, then:
#
# - count(h, w) = 0
#
# - so P(w | h) = 0
#
# This causes two serious problems:
#
# Zero probability chains
# If any word in a sentence has probability 0, the probability of the entire sentence becomes 0.
#
# Infinite perplexity
# Log probability of 0 is undefined, so evaluation breaks.

# %%
def prob_addk(ngram, ngram_counts, context_counts, k=0.5):
    """ Computes add-k smoothed probability for an n-gram."""
    V = len(vocab)  # Vocabulary size for smoothing.
    return (ngram_counts[ngram] + k) / (context_counts[ngram[:-1]] + k*V)  # Add-k smoothing formula.

# %% [markdown]
# ## 10. Perplexity evaluation

# %%
# Evaluate perplexity on test set
def perplexity(docs, n, ngram_counts, context_counts, k=0.5):
    """ Calculates perplexity of the given n-gram model on the provided documents."""
    log_prob = 0  # Total log probability of the test set.
    count = 0  # Total number of n-grams in the test set.

    for d in docs:
        toks = replace_oov(tokenize(d))
        toks = add_boundaries(toks, n)
        for ng in get_ngrams(toks, n):
            p = prob_addk(ng, ngram_counts, context_counts, k)  # Probability of the n-gram.
            log_prob += math.log2(p)  # Use log2 for perplexity calculation to avoid large numbers.
            count += 1

    H = -log_prob / count  # Compute cross-entropy
    return 2**H  # Perplexity is 2 raised to the cross-entropy.

# Compare perplexities. Lower perplexity is better."

print("Unigram:", perplexity(test_docs, 1, uni_counts, uni_ctx))
print("Bigram :", perplexity(test_docs, 2, bi_counts, bi_ctx))
print("Trigram:", perplexity(test_docs, 3, tri_counts, tri_ctx))
# Out:
# Unigram: 770.7568679909757
# Bigram : 532.3717185195632
# Trigram: 2556.0951062679683

# %% [markdown]
# ## 11. Next-word prediction

# %%
def next_word(context, n, ngram_counts, context_counts, top_k=5):
    """ Predicts the top_k next words given the context using the n-gram model."""
    context = tuple(context[-(n-1):]) if n > 1 else tuple()  # Uses last (n-1) words as context.
    scores = []
    for w in vocab:
        if w == "<s>": # Prevents predicting start-of-sentence token
            continue
        ng = context + (w,)  # Forms the candidate n-gram.
        scores.append((w, prob_addk(ng, ngram_counts, context_counts)))  # Scores the candidate word.
    scores.sort(key=lambda x: -x[1])
    return scores[:top_k]

next_word(["oil", "prices"], 3, tri_counts, tri_ctx)
# Out:
# [('and', 0.004929346040092014),
#  ('to', 0.001643115346697338),
#  ('would', 0.001643115346697338),
#  ('was', 0.0014240333004710264),
#  ('but', 0.0012049512542447146)]

# %%
print("oil in vocab:", "oil" in vocab)
print("prices in vocab:", "prices" in vocab)
# Out:
# oil in vocab: True
# prices in vocab: True

# %%
print("Context count tri_ctx[('oil','prices')]:", tri_ctx[("oil","prices")])
# Out:
# Context count tri_ctx[('oil','prices')]: 178

# %%
candidates = []
for w in vocab:
    if w in {"<s>"}:
        continue
    candidates.append((w, tri_counts[("oil","prices",w)]))

sorted(candidates, key=lambda x: -x[1])[:20]
# Out:
# [('and', 22),
#  ('to', 7),
#  ('would', 7),
#  ('was', 6),
#  ('but', 5),
#  ('the', 5),
#  ('</s>', 5),
#  ('in', 5),
#  ('rose', 5),
#  ('were', 5),
#  ('are', 5),
#  ('from', 4),
#  ('on', 4),
#  ('by', 4),
#  ('which', 4),
#  ('should', 4),
#  ('last', 3),
#  ('at', 3),
#  ('it', 3),
#  ('<UNK>', 3)]

# %% [markdown]
# ## Why this pipeline matters
#
# This notebook mirrors real NLP systems:
#
# - deterministic preprocessing
# - explicit vocabulary
# - train/validate/test separation
# - quantitative evaluation
# - API-style inference
#
# Neural language models build on the same principles.
